# %%
source("../Scripts/functions.R")
source("../Scripts/visulizations.r")
library(ggplot2)
library(dplyr)
library(purrr)
library(Seurat)
library(viridis)
library("RColorBrewer")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: viridisLite

# %%
celltypes = c("Cytotoxic T cell", "CD4+ T cell", "CD14+ monocyte", "B cell", "Megakaryocyte", "Natural killer cell",
              "CD16+ monocyte", "Dendritic cell", "Plasmacytoid dendritic cell")
methods <- c("Seurat",  "SingleR","CellID", "SCN", "ItClust")
sizes <- c(3090, 2418, 1373, 1022, 703, 623, 273, 126, 23)
names(sizes) <- celltypes

colors <-brewer.pal(length(celltypes), "Paired")
names(colors) <- celltypes

# %%
prepare_umap <- function(file,  meta_data, normalization_method="L1", min_cells=3, hvgs=500, split=NULL){
    data <- readData(file)
    data <- data[, colnames(data) %in% rownames(meta_data)]

    meta_data <- meta_data[rownames(meta_data)%in% colnames(data),]
    data <- data[!(rowSums(data != 0) < min_cells),]

    meta_data <- meta_data[meta_data$id %in% colnames(data),]
    rownames(meta_data) <- meta_data$id
    print(hvgs)
    data <- select_hvg(data, hvgs)
    if(!is.null(split)){

      sets <- lapply(unique(meta_data[, split]), function(s) data[, colnames(data) %in% meta_data$id[meta_data[,split] == s]])
      data <- batchelor::fastMNN(sets)
      data <-  SummarizedExperiment::assay(data, "reconstructed")
    } else{

        # Cell wise (Result: Sum of each row = 1)
        if(normalization_method == "L1"){
            data <- apply(data, 2, normalize_l1)
        }else if(normalization_method == "L2") data <- apply(data, 2, normalize_l2)

    }

    print("Scaling...")
    # Gene wise (Variance of each column is 1, mean = 0) (Colum should be Gene)
    data <- t(scale(t(data), center = TRUE, scale = TRUE))
    
    print("create seurat object....")   
    pbmc <- Seurat::CreateSeuratObject(as.matrix(data), meta.data = meta_data)

    print("Set assay....")                 
    pbmc <- Seurat::SetAssayData(pbmc, assay = "RNA", slot = "scale.data", new.data = as.matrix(data))
    
    print("PCA....")
    pbmc <- Seurat::RunPCA(pbmc, features = rownames(data),verbose = F)
    print("Get UMAP...")
    pbmc <- Seurat::RunUMAP(pbmc, dims = 1:10, verbose = F)
    return(pbmc)
}

translate <- function(col){
  
    col[col == "B"] <- "B cell"
    col[col == "Cytotoxic T"] <- "Cytotoxic T cell"
    col[col == "CD4+ T"] <- "CD4+ T cell"
    col[col == "Dendritic"] <- "Dendritic cell"
    col[col == "Natural killer"] <- "Natural killer cell"
    col[col == "Plasmacytoid dendritic"] <- "Plasmacytoid dendritic cell"
    return(col)
}

# %%
umapdata <- read.csv("../Results/Files/results_PBMC10x.csv")
expressiondata_file="../Data/Fulldata//PBMC_Query/data.csv"
umap <- prepare_umap(file = expressiondata_file, meta_data = umapdata, split = "Method")



#"alphabet", "alphabet2", "glasbey", "polychrome", and "stepped"

plot_celltypes = plot_umap(umap, c("class_"),NULL, colors,1,1, legend_ncol = 2)

f1a <- plot_celltypes[[1]]

umap@meta.data$PBMC10x_SCN_3090_0[umap@meta.data$PBMC10x_CellID_3090_0 == "unassigned"] <- NA
plots_full <- plot_umap(umap, c(paste0("PBMC10x_",methods, "_3090_0")),NULL,color=colors, 1,1, legend_ncol = 5) 

f1b <- ggpubr::ggarrange(plotlist = plots_full, font.label = list(size = 15), #labels=methods,
                         common.legend = F, legend = "none", ncol=1, nrow=5)
# Out:
# Warning message in data.table::fread(data, sep = ",", verbose = F):
# “Detected 10910 column names but the data has 10911 columns (i.e. invalid file). Added 1 extra default column name for the first column which is guessed to be row names or an index. Use setnames() afterwards if this guess is not correct, or fix the file write command that created the file to create a valid file.”
# [1] 500
# [1] "Scaling..."
# Warning message:
# “Argument 'center' should be of the same length as number of rows of 'x'. Use of a scalar value is deprecated: 1 != 500”
# [1] "create seurat object...."
# [1] "Set assay...."
# [1] "PCA...."
# [1] "Get UMAP..."
# Warning message:
# “The default method for RunUMAP has changed from calling Python UMAP via reticulate to the R-native UWOT using the cosine metric
# To use Python UMAP via reticulate, set umap.method to 'umap-learn' and metric to 'correlation'
# This message will be shown once per session”

# %%
data <- read.csv("../Results/Files/results_PBMC10x_long.csv")
data_accuracy <- calculate_accuracy(data)
data_accuracy <- data_accuracy[data_accuracy$Size == 3090,]
data_accuracy$Approach <- factor(data_accuracy$Approach, levels=methods)
data_accuracy$class <- factor(data_accuracy$class, levels=celltypes)
table(data$Match)
options(repr.plot.width=10, repr.plot.height=5)
f1c <- ggplot(data_accuracy, aes(class, accuracy, fill=class)) + geom_bar(stat="identity") +
        facet_grid(rows = vars(Approach)) + geom_text(aes(label=round(accuracy,2)), vjust=1.5, size=3, color="white") + 
        scale_fill_manual(values=colors) + theme_bw() + ylab("Accuracy") + xlab("") + 
        theme(axis.text.x = element_blank(), legend.position = "none")
f1c
# Out:
# `summarise()` has grouped output by 'Size', 'Approach', 'Reference', 'class', 'Set'. You can override using the `.groups`
# argument.
#    FALSE     TRUE
# 19915995 54933556
# plot without title

# %%
get_measures <- function(data, type){
    tp <- length(data$Prediction[data$Prediction == type & data$class == type])
    fp <- length(data$Prediction[data$Prediction == type & data$class != type])
    fn <- length(data$Prediction[data$Prediction != type & data$class == type])
    tn <- length(data$Prediction[data$Prediction != type & data$class != type])
    
    precision <- tp / (tp + fp)
    recall <- tp / (tp + fn)
    f1 <- 2(precision * recall) / (precision + recall)
    accuracy <- (tp + tn) + nrow(data)
}
    
    head(data)
# Out:
#   id                            Prediction          Reference Approach Size Set
# 1 pbmc2_10X_V2_AAACCTGAGATGGGTC B cell              PBMC10x   CellID   100  1
# 2 pbmc2_10X_V2_AAACCTGAGCGTAATA B cell              PBMC10x   CellID   100  1
# 3 pbmc2_10X_V2_AAACCTGAGCTAGGCA Natural killer cell PBMC10x   CellID   100  1
# 4 pbmc2_10X_V2_AAACCTGAGGGTCTCC Dendritic cell      PBMC10x   CellID   100  1
# 5 pbmc2_10X_V2_AAACCTGGTCCGAACC CD4+ T cell         PBMC10x   CellID   100  1
# 6 pbmc2_10X_V2_AAACCTGTCGTCCGTT Cytotoxic T cell    PBMC10x   CellID   100  1
#   class            refSize Match
# 1 B cell           1022     TRUE
# 2 B cell           1022     TRUE
# 3 Cytotoxic T cell 3090    FALSE
# 4 Dendritic cell    126     TRUE
# 5 CD4+ T cell      2418     TRUE
# 6 CD4+ T cell      2418    FALSE

# %%
options(repr.plot.width=15, repr.plot.height=10)  
f1bc <- ggpubr::ggarrange(f1b, f1c, nrow=1, ncol=2, labels= c("B", "C"))
f1 <- ggpubr::ggarrange(f1a,f1bc, nrow=2, ncol=1, heights=c(1,4), labels= c("A"))
f1
# Out:
# plot without title

# %%
ggsave(
  "../Results/Figures/F1_PBMC_full.pdf",
  plot = f1,
  device = "pdf",
  path = NULL,
  scale = 1,
  width = 165,
  height = 200,
  units = "mm",
  dpi = 300,
  limitsize = TRUE,
  bg = NULL
)

# %%
library(sleepwalk)
sleepwalk( Embeddings(Reductions(umap, "umap")), Embeddings(Reductions(umap, "pca")) )
# Out:
# Estimating 'maxdist' for feature matrix 1
#
# Server has been stopped.
# Error in browseURL(str_c("http://localhost:", private$port), browser = browser): 'browser' must be a non-empty character string
# Traceback:
#
# 1. sleepwalk(Embeddings(Reductions(umap, "umap")), Embeddings(Reductions(umap,
#  .     "pca")))
# 2. jrc::openPage(useViewer = FALSE, rootDirectory = system.file(package = "sleepwalk"),
#  .     startPage = paste0(system.file(package = "sleepwalk"), "/sleepwalk_",
#  .         mode, ".html"), ...)
# 3. app$openPage(useViewer, browser)
# 4. browseURL(str_c("http://localhost:", private$port), browser = browser)
# 5. stop("'browser' must be a non-empty character string")

# %%
library(Seurat)
library(SeuratDisk)
library(SeuratData)
# Out:
# Attaching SeuratObject
# Error in library(SeuratDisk): there is no package called ‘SeuratDisk’
# Traceback:
#
# 1. library(SeuratDisk)
